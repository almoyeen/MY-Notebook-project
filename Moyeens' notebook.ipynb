# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# #### Abdullah Al Moyeen
# Want to be a data analyst

# %% [markdown]
# *I want to be an data analyst beacause it getting higher demand day by day.*

# %% [markdown]
# ### The following code tests the Gauss formula

# %%
def gauss(n):
    return(n*(n+1))/2
gauss(100)== sum (range(101))
# Out:
# True

# %% [markdown]
# | Name |Age |Class |
# |------|----|------|
# | Moyeen | 23 | B.Sc 4th year |
# | Raiyana | 23 | B.Sc 4th year |
#
# ---
#
# *Hi
# *
# *
